# %% [markdown]
# # Knapsack Problem

# %%
from main import knapsack
from ea import EvolutionaryAlgorithm

# %% [markdown]
# ## Knapsack 1

# %%
with open('../knapsack_1.txt') as f:
    m = knapsack(f)
alg = EvolutionaryAlgorithm(10, 20, 1000, m, window_size=1000, threshold=-1)
print(alg.run())
# Out:
# weight: 995, value: 4371 with fitness: 4371

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots(figsize=(20, 8))

ax.plot(alg.average_fitness, '-o')
ax.set_xlabel('Generation')
ax.set_ylabel('Average Fitness')
# Out:
# Text(0, 0.5, 'Average Fitness')

# %% [markdown]
# Here we cannot find a feasible solution. The final fitness and average fitness is not above 1 so there is no feasible soltion to given knapsack problem.

# %% [markdown]
# ## Knapsack 2

# %%
with open('../knapsack_2.txt') as f:
    m = knapsack(f)
alg = EvolutionaryAlgorithm(10, 20, 1000, m, window_size=1000, threshold=-1)
print(alg.run())
# Out:
# weight: 978, value: 1032 with fitness: 1032

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots(figsize=(20, 8))

ax.plot(alg.average_fitness, '-o')
ax.set_xlabel('Generation')
ax.set_ylabel('Average Fitness')
# Out:
# Text(0, 0.5, 'Average Fitness')

# %% [markdown]
# Here we cannot find a feasible solution. The final fitness and average fitness is not above 1 so there is no feasible soltion to given knapsack problem.

# %% [markdown]
# ## Knapsack 3

# %%
with open('../knapsack_3.txt') as f:
    m = knapsack(f)
alg = EvolutionaryAlgorithm(10, 20, 1000, m, window_size=1000, threshold=-1)
print(alg.run())
# Out:
# weight: 995, value: 1595 with fitness: 1595

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots(figsize=(20, 8))

ax.plot(alg.average_fitness, '-o')
ax.set_xlabel('Generation')
ax.set_ylabel('Average Fitness')
# Out:
# Text(0, 0.5, 'Average Fitness')
